# %%
using JSON
using Embeddings
using MultivariateStats
using Plots
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
words = JSON.parsefile("../data/words.json")
words_by_class = collect(values(words))
all_words = reduce(vcat, words_by_class)
embedding_table = load_embeddings(Word2Vec; keep_words=all_words)
@assert Set(all_words) == Set(embedding_table.vocab)

# %%
embeddings = embedding_table.embeddings
all_words = embedding_table.vocab
classes = map(all_words) do word
    findfirst(col -> word ∈ col, words_by_class)
end;

# %% [markdown]
# # PCA

# %%
M = fit(PCA, embeddings; maxoutdim=3)
xs = transform(M, embeddings)
scatter(xs[1,:], xs[2,:], xs[3,:]; hover=all_words, zcolor=classes, legend=false)
# Out:
#     <div id="47237ba0-a6d9-47fc-891f-c18e898011a2" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('47237ba0-a6d9-47fc-891f-c18e898011a2', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "China"
#         ],
#         "x": [
#             0.13617751
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.1742851
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.31204748
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "field"
#         ],
#         "x": [
#             -0.2593405
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.06294403
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.025029572
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "Iraq"
#         ],
#         "x": [
#             0.07097494
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.0044485154
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.18318689
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "Washington"
#         ],
#         "x": [
#             0.091963135
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             -0.07040516
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(187, 55, 85, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.32591712
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "India"
#         ],
#         "x": [
#             0.132599
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.29161462
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.3701638
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "South"
#         ],
#         "x": [
#             -0.13540742
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.19717838
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.027997507
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "football"
#         ],
#         "x": [
#             -0.5829913
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             -0.18035758
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.027392212
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "Canada"
#         ],
#         "x": [
#             0.003665872
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             0.3767408
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.1859642
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "London"
#         ],
#         "x": [
#             0.17408487
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "z": [
#             -0.14365363
#         ],
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(252, 255, 164, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.14762346
#         ],
#         "type": "scatter3d",
#         "scene": "scene",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "zaxis": "z",
#         "text": [
#             "England"
#         ],
#         "x": [
#             -0.04375909
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",

# %%
M = fit(PCA, embeddings; maxoutdim=2)
xs = transform(M, embeddings)
scatter(xs[1,:], xs[2,:]; hover=all_words, zcolor=classes, legend=false)
# Out:
#     <div id="ca02fae2-5c24-4ce9-b7e6-bc235d7789dc" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('ca02fae2-5c24-4ce9-b7e6-bc235d7789dc', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "China"
#         ],
#         "x": [
#             0.13617751
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.31204748
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "field"
#         ],
#         "x": [
#             -0.2593405
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.025029572
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Iraq"
#         ],
#         "x": [
#             0.07097494
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.18318689
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Washington"
#         ],
#         "x": [
#             0.091963135
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(187, 55, 85, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.32591712
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "India"
#         ],
#         "x": [
#             0.132599
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.3701638
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "South"
#         ],
#         "x": [
#             -0.13540742
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.027997507
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "football"
#         ],
#         "x": [
#             -0.5829913
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.027392212
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Canada"
#         ],
#         "x": [
#             0.003665872
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.1859642
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "London"
#         ],
#         "x": [
#             0.17408487
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(252, 255, 164, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             0.14762346
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "England"
#         ],
#         "x": [
#             -0.04375909
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             -0.08436842
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Australia"
#         ],
#         "x": [
#             0.064135216
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             }

# %%
M = fit(PCA, embeddings; maxoutdim=1)
xs = transform(M, embeddings)
scatter(xs[1,:], ones(length(xs)); hover=all_words, zcolor=classes, legend=false)
# Out:
#     <div id="96d47032-5e7b-474f-b8d7-10f061f3b0f3" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('96d47032-5e7b-474f-b8d7-10f061f3b0f3', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "China"
#         ],
#         "x": [
#             0.13617751
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "field"
#         ],
#         "x": [
#             -0.2593405
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Iraq"
#         ],
#         "x": [
#             0.07097494
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Washington"
#         ],
#         "x": [
#             0.091963135
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(187, 55, 85, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "India"
#         ],
#         "x": [
#             0.132599
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "South"
#         ],
#         "x": [
#             -0.13540742
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "football"
#         ],
#         "x": [
#             -0.5829913
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(87, 16, 109, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Canada"
#         ],
#         "x": [
#             0.003665872
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "London"
#         ],
#         "x": [
#             0.17408487
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(252, 255, 164, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "England"
#         ],
#         "x": [
#             -0.04375909
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "text": [
#             "Australia"
#         ],
#         "x": [
#             0.064135216
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "y1",
#         "zmin": 1.0,
#         "legendgroup": "y1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 0, 4, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": 5.0,
#         "y": [
